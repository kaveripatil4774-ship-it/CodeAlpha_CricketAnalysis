# %% [markdown]
# <a href="https://colab.research.google.com/github/kaveripatil4774-ship-it/CodeAlpha_CricketAnalysis/blob/main/Untitled6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Task 2 (EDA) & Task 3 (Data Visualization)
# Topic: Simple IPL Cricket Data Analysis

import pandas as pd
import matplotlib.pyplot as plt

# 1. Create Simple IPL Dataset (RCB = 2 Corrected)
data = {
    'Team': ['Mumbai Indians', 'Chennai Super Kings', 'Kolkata Knight Riders', 'RCB', 'Delhi Capitals'],
    'Total_Wins': [5, 5, 3, 2, 0]
}
df = pd.DataFrame(data)

# --- TASK 2: EXPLORATORY DATA ANALYSIS (EDA) ---
print("--- Dataset Overview ---")
print(df.head())           # Display data
print("\nDataset Info:")
print(df.info())           # Check structure

# --- TASK 3: DATA VISUALIZATION ---
plt.figure(figsize=(7, 4))
plt.bar(df['Team'], df['Total_Wins'], color='skyblue')
plt.title('IPL Trophy Wins by Team')
plt.xlabel('Teams')
plt.ylabel('Trophies Won')
plt.xticks(rotation=30)
plt.show()

print("\nAnalysis Completed Successfully!")
# Out:
# --- Dataset Overview ---
#                     Team  Total_Wins
# 0         Mumbai Indians           5
# 1    Chennai Super Kings           5
# 2  Kolkata Knight Riders           3
# 3                    RCB           2
# 4         Delhi Capitals           0
#
# Dataset Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Team        5 non-null      object
#  1   Total_Wins  5 non-null      int64
# dtypes: int64(1), object(1)
# memory usage: 212.0+ bytes
# None
# Analysis Completed Successfully!
